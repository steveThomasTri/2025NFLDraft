# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("cleaned_NFL_combine_2000_to_2024.csv")
df.head()
# Out:
#    year              name             college position  height_in  weight_lbs  \
# 0  2000    darnell alford      Boston College       OT       76.0       334.0
# 1  2000      kyle allamon          Texas Tech       TE       74.5       253.0
# 2  2000  rashard anderson  Jackson State (MS)       CB       74.4       206.0
# 3  2000      corey atkins      South Carolina      OLB       72.4       237.0
# 4  2000     reggie austin         Wake Forest       CB       69.4       175.0
#
#    40yards  benchpress  vert_leap_in  broad_jump_in  shuttle  3cone drafted
# 0     5.58        23.0          25.0           94.0     4.98    NaN       1
# 1     5.01         NaN          29.0          104.0     4.49    NaN       N
# 2     4.59         NaN          34.0          123.0     4.15    NaN       1
# 3     4.76        21.0          31.0          112.0     4.39    NaN       N
# 4     4.46        17.0          35.0          119.0     4.14    NaN       1

# %%
df.describe()
# Out:
#               year    height_in   weight_lbs      40yards   benchpress  \
# count  6977.000000  6977.000000  6977.000000  6571.000000  4981.000000
# mean   2011.793464    73.907920   244.222159     4.781736    20.853845
# std       6.939815     2.634607    45.706272     0.308882     6.334320
# min    2000.000000    65.000000   149.000000     4.210000     2.000000
# 25%    2006.000000    72.000000   206.000000     4.540000    16.000000
# 50%    2012.000000    74.100000   234.000000     4.690000    21.000000
# 75%    2017.000000    75.880000   285.000000     4.990000    25.000000
# max    2024.000000    81.630000   384.000000     6.070000    49.000000
#
#        vert_leap_in  broad_jump_in      shuttle      3cone
# count   5990.000000    5888.000000  4756.000000  77.000000
# mean      32.941836     114.579654     4.398911   7.296364
# std        4.233216       9.426863     0.268891   0.400739
# min       17.500000      73.000000     3.730000   6.620000
# ...

# %%
#find all correlations
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 2
#       1 #find all correlations
# ----> 2 corr = df.corr()
#       3 corr.style.background_gradient(cmap='coolwarm')
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\frame.py:11049, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11047 cols = data.columns
#   11048 idx = cols.copy()
# > 11049 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11051 if method == "pearson":
#   11052     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\frame.py:1993, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1991 if dtype is not None:
#    1992     dtype = np.dtype(dtype)
# -> 1993 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1994 if result.dtype is not dtype:
# ...

# %%
df.columns
# Out:
# Index(['year', 'name', 'college', 'position', 'height_in', 'weight_lbs',
#        '40yards', 'benchpress', 'vert_leap_in', 'broad_jump_in', 'shuttle',
#        '3cone', 'drafted'],
#       dtype='object')

# %%
df_numeric = df.select_dtypes(include='number')
corr_matrix = df_numeric.corr()

# %%
corr_matrix.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_8ad37_row0_col0, #T_8ad37_row1_col1, #T_8ad37_row2_col2, #T_8ad37_row3_col3, #T_8ad37_row4_col4, #T_8ad37_row5_col5, #T_8ad37_row6_col6, #T_8ad37_row7_col7, #T_8ad37_row8_col8 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_8ad37_row0_col1, #T_8ad37_row6_col0 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_8ad37_row0_col2 {
#   background-color: #bed2f6;
#   color: #000000;
# }
# #T_8ad37_row0_col3 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_8ad37_row0_col4 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_8ad37_row0_col5 {
#   background-color: #cad8ef;
#   color: #000000;
# }
# #T_8ad37_row0_col6, #T_8ad37_row7_col4 {
#   background-color: #eed0c0;
#   color: #000000;
# }
# #T_8ad37_row0_col7 {
#   background-color: #d4dbe6;
#   color: #000000;
# }
# #T_8ad37_row0_col8, #T_8ad37_row8_col0 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_8ad37_row1_col0 {
# ...

# %%
# + 3cone & shuttle +0.893289
# + weight_lbs & 40yards +0.860706
# - broad_jump & 40 yards -0.823387

# %%
df[df["40yards"].isnull()].head()
# Out:
#       year             name               college position  height_in  \
# 1718  2006    marcus hudson  North Carolina State       FS      73.13
# 1739  2006  winston justice   Southern California       OT      78.13
# 1769  2006    tim massaquoi              Michigan       TE      74.63
# 1811  2006      donald penn            Utah State       OT      76.25
# 1855  2006   adam stenavich              Michigan       OG      76.00
#
#       weight_lbs  40yards  benchpress  vert_leap_in  broad_jump_in  shuttle  \
# 1718       194.0      NaN        11.0           NaN            NaN      NaN
# 1739       319.0      NaN         NaN          35.0          110.0     4.53
# 1769       259.0      NaN        32.0           NaN            NaN      NaN
# 1811       317.0      NaN        21.0           NaN            NaN      NaN
# 1855       310.0      NaN        24.0           NaN            NaN      NaN
#
#       3cone drafted
# 1718    NaN       1
# 1739    NaN       1
# 1769    NaN       1
# ...

# %%
df.groupby(["position", "drafted"])["40yards"].describe()
# Out:
#                   count      mean       std   min     25%    50%     75%   max
# position drafted
# C        1        123.0  5.223171  0.148784  4.89  5.1400  5.230  5.3250  5.58
#          N         64.0  5.264687  0.187566  4.82  5.1450  5.260  5.3900  5.84
# CB       1        517.0  4.478337  0.082980  4.23  4.4200  4.480  4.5300  4.76
#          N        194.0  4.563608  0.101043  4.33  4.4900  4.570  4.6300  4.95
# DB       1          3.0  4.466667  0.080829  4.38  4.4300  4.480  4.5100  4.54
# DE       1        378.0  4.792831  0.136357  4.48  4.6925  4.790  4.8800  5.26
#          N        139.0  4.915468  0.136468  4.63  4.8200  4.920  5.0000  5.27
# DL       1          3.0  4.756667  0.040415  4.72  4.7350  4.750  4.7750  4.80
#          N          1.0  4.880000       NaN  4.88  4.8800  4.880  4.8800  4.88
# DT       1        358.0  5.078296  0.160614  4.67  4.9725  5.075  5.1800  5.71
#          N        146.0  5.157123  0.158949  4.81  5.0400  5.150  5.2775  5.62
# ...
