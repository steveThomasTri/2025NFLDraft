# %%
import numpy as np
import pandas as pd

import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
df = pd.read_csv("cleaned_NFL_combine_2000_to_2024.csv")
df = df[(df["position"] != "NT") & (df["position"] != "K") & (df["position"] != "LS")]

# %%
df
# Out:
#       year              name               college position  height_in  \
# 0     2000    darnell alford        Boston College       OT      76.00
# 1     2000      kyle allamon            Texas Tech       TE      74.50
# 2     2000  rashard anderson    Jackson State (MS)       CB      74.40
# 3     2000      corey atkins        South Carolina      OLB      72.40
# 4     2000     reggie austin           Wake Forest       CB      69.40
# ...    ...               ...                   ...      ...        ...
# 6972  2024     payton wilson  North Carolina State      OLB      75.88
# 6973  2024      roman wilson              Michigan       WR      70.75
# 6974  2024       mekhi wingo       Louisiana State       DT      72.25
# 6975  2024     xavier worthy                 Texas       WR      71.25
# 6976  2024     jaylen wright             Tennessee       RB      70.50
#
#       weight_lbs  40yards  benchpress  vert_leap_in  broad_jump_in  shuttle  \
# 0          334.0     5.58        23.0          25.0           94.0     4.98
# 1          253.0     5.01         NaN          29.0          104.0     4.49
# 2          206.0     4.59         NaN          34.0          123.0     4.15
# 3          237.0     4.76        21.0          31.0          112.0     4.39
# 4          175.0     4.46        17.0          35.0          119.0     4.14
# ...          ...      ...         ...           ...            ...      ...
# 6972       233.0     4.43         NaN          34.5          119.0      NaN
# 6973       185.0     4.39        12.0           NaN            NaN      NaN
# 6974       284.0     4.85        25.0          31.5          109.0      NaN
# 6975       165.0     4.21         NaN          41.0          131.0      NaN
# 6976       210.0     4.38         NaN          38.0          134.0      NaN
#
#       3cone drafted
# 0       NaN       1
# 1       NaN       N
# 2       NaN       1
# 3       NaN       N
# 4       NaN       1
# ...     ...     ...
# 6972    NaN       1
# 6973    NaN       1
# 6974    NaN       1
# 6975    NaN       1
# 6976    NaN       1
#
# [6946 rows x 13 columns]

# %%
#df = pd.read_csv("cleaned_NFL_combine_97_to_2018.csv")
df = df.drop(["year","name","college","position"],axis='columns')
df.head()
# Out:
#    height_in  weight_lbs  40yards  benchpress  vert_leap_in  broad_jump_in  \
# 0       76.0       334.0     5.58        23.0          25.0           94.0
# 1       74.5       253.0     5.01         NaN          29.0          104.0
# 2       74.4       206.0     4.59         NaN          34.0          123.0
# 3       72.4       237.0     4.76        21.0          31.0          112.0
# 4       69.4       175.0     4.46        17.0          35.0          119.0
#
#    shuttle  3cone drafted
# 0     4.98    NaN       1
# 1     4.49    NaN       N
# 2     4.15    NaN       1
# 3     4.39    NaN       N
# 4     4.14    NaN       1

# %%
Y = df["drafted"]
Y = Y.replace("N",0)

X = df.drop(["drafted"], axis='columns')

# %%
# Out:
# 0       1
# 1       0
# 2       1
# 3       0
# 4       1
#        ..
# 6972    1
# 6973    1
# 6974    1
# 6975    1
# 6976    1
# Name: drafted, Length: 6946, dtype: object

# %%
# split data into train and test sets
seed = 777
test_size = 0.30
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=test_size, random_state=seed)

# %%
# fit model on training data
model = xgb.XGBRegressor(objective="binary:logistic", random_state=42)
model.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[25], line 2
#       1 # fit model on training data
# ----> 2 model = xgb.XGBRegressor(objective="binary:logistic", random_state=42)
#       3 model.fit(X_train, y_train)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\xgboost\core.py:729, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     727 for k, arg in zip(sig.parameters, args):
#     728     kwargs[k] = arg
# --> 729 return func(**kwargs)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\xgboost\sklearn.py:1879, in XGBRegressor.__init__(self, objective, **kwargs)
#    1875 @_deprecate_positional_args
#    1876 def __init__(
#    1877     self, *, objective: SklObjective = "reg:squarederror", **kwargs: Any
#    1878 ) -> None:
# -> 1879     super().__init__(objective=objective, **kwargs)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\xgboost\core.py:729, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     727 for k, arg in zip(sig.parameters, args):
#     728     kwargs[k] = arg
# --> 729 return func(**kwargs)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\xgboost\sklearn.py:772, in XGBModel.__init__(self, max_depth, max_leaves, max_bin, grow_policy, learning_rate, n_estimators, verbosity, objective, booster, tree_method, n_jobs, gamma, min_child_weight, max_delta_step, subsample, sampling_method, colsample_bytree, colsample_bylevel, colsample_bynode, reg_alpha, reg_lambda, scale_pos_weight, base_score, random_state, missing, num_parallel_tree, monotone_constraints, interaction_constraints, importance_type, device, validate_parameters, enable_categorical, feature_types, feature_weights, max_cat_to_onehot, max_cat_threshold, multi_strategy, eval_metric, early_stopping_rounds, callbacks, **kwargs)
#     723 @_deprecate_positional_args
#     724 def __init__(
#     725     self,
#    (...)    769     **kwargs: Any,
#     770 ) -> None:
#     771     if not SKLEARN_INSTALLED:
# --> 772         raise ImportError(
#     773             "sklearn needs to be installed in order to use this module"
#     774         )
#     775     self.n_estimators = n_estimators
#     776     self.objective = objective
#
# ImportError: sklearn needs to be installed in order to use this module
